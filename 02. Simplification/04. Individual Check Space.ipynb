# %%
import numpy as np
from astropy.io import fits
from marvin.tools import Maps
import marvin.utils.plot.colorbar as colorbar
from tqdm import tqdm
import matplotlib.pyplot as plt
#from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import scipy as scipy
from scipy.fft import fft
from scipy import ndimage

import multiprocessing as mp
from multiprocessing import Pool
import copy

import Simpler_Classifier

from importlib import reload
# Out:
# [INFO]: No release version set. Setting default to DR17
# [WARNING]: path /Users/runquanguan/sas/mangawork/manga/spectro/redux/v3_1_1/drpall-v3_1_1.fits cannot be found. Setting drpall to None. (MarvinUserWarning)
# [WARNING]: path /Users/runquanguan/sas/mangawork/manga/spectro/analysis/v3_1_1/3.1.0/dapall-v3_1_1-3.1.0.fits cannot be found. Setting dapall to None. (MarvinUserWarning)
# [WARNING]: Passing field metadata as keyword arguments is deprecated. Use the explicit `metadata=...` argument instead. Additional metadata: {'location': 'view_args'} (RemovedInMarshmallow4Warning)
# [WARNING]: The 'missing' argument to fields is deprecated. Use 'load_default' instead. (RemovedInMarshmallow4Warning)

# %%
#data = '9024-3701'
my_module = reload(Simpler_Classifier) # reload of Simpler_Classifier without restart

# %%
curve = Simpler_Classifier.ew_integ(data, test = True)
result = Simpler_Classifier.fourier_classifier(curve)
result
# Out:
# [WARNING]: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray. (VisibleDeprecationWarning)
# ([1.0,
#   0.4823263160293728,
#   0.30969030450581464,
#   0.2233192501580869,
#   0.17145998213919147,
#   0.13686229030991504,
#   0.11213366731443615,
#   0.0935779874302483,
#   0.07914174492748623,
#   0.06759257420979944,
#   0.05814588187386057,
#   0.05027819717396336,
#   0.043626701506745975,
#   0.03793184569368426,
#   0.03300294363437385,
#   0.028696685235254458,
#   0.024903243660757187,
#   0.021537018642425573,
#   0.018530303686086005,
#   0.015828850685588827,
#   0.013388697406299213,
#   0.011173854913169495,
#   0.009154592898462864,
#   0.007306148754852277,
#   0.005607742312357812,
#   0.0040418146575017955,
#   0.0025934336577641084,
#   0.0012498251531681524,
#   0.0],
# ...

# %%
Simpler_Classifier.plot_compared(data, save = False)
# Out:
# [WARNING]: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray. (VisibleDeprecationWarning)
# [WARNING]: showImage is deprecated as of Marvin 2.3.0. Please use marvin.tools.image.Image instead. (MarvinDeprecationWarning)
# [WARNING]: subprocess 18516 is still running (ResourceWarning)

# %%
HEADER_PATH = '/Users/runquanguan/Documents/simpler_FULL_AUTO_v5.fits'
hdul = fits.open(HEADER_PATH)
hdu = hdul[1].data
plateifu = hdu['PLATEIFU']

# %%
rand = np.random.randint(len(plateifu), size=50)

# %%
def rand_check(n):
    data = plateifu[n]
    print(data)
    Simpler_Classifier.plot_compared(data)

# %%
for n in tqdm(rand):
    data = plateifu[n]
    Simpler_Classifier.plot_compared(data)
# Out:
# ...
#   8%|▊         | 4/50 [01:54<21:59, 28.69s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-2aef21ce41ae> in <module>
#       1 for n in tqdm(rand):
#       2     data = plateifu[n]
# ----> 3     Simpler_Classifier.plot_compared(data)
#
# ~/Documents/Research/MaNGA-AGN/02. Simplification/Simpler_Classifier.py in plot_compared(data, snr, save)
#     381     fig.set_figwidth(15)
#     382     plt.title("Image")
# --> 383     im = Image(data)
#     384     spaxel_len = 281*2
#     385     factor = spaxel_len / axis_indicat.shape[0]
#
# ~/anaconda3/lib/python3.7/site-packages/marvin/tools/image.py in __init__(self, input, filename, mangaid, plateifu, mode, data, release, download)
#      75             raise MarvinError('Images cannot currently be accessed from the db')
#      76         elif self.data_origin == 'api':
# ...
