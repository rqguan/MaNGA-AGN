# %% [markdown]
# Info b
#
# https://sdss-marvin.readthedocs.io/en/latest/tools/image.html

# %%
# %matplotlib inline

# %%
import numpy as np
from astropy.io import fits
from marvin.tools import Maps
from tqdm import tqdm
import Bicone_Classifier
import multiprocessing as mp
import copy
import matplotlib.pyplot as plt
from marvin.utils.general.images import showImage
from marvin.tools.image import Image

from scipy import ndimage

# %%
HEADER_PATH = '/Users/runquanguan/Documents/dapall-v3_1_1-3.1.0.fits'
hdul = fits.open(HEADER_PATH)
hdu = hdul[1].data
plateifu = hdu['PLATEIFU']
petro_angle = hdu['NSA_ELPETRO_PHI']
sersic_angle = hdu['NSA_SERSIC_PHI']

# %%
def plot_major_axis(data):
    

    dapall_index = list(plateifu).index(data)
    p_slope = np.tan(petro_angle[dapall_index])
    s_slope = np.tan(sersic_angle[dapall_index])

    maps = Maps(data, bintype='SPX', template='MILESHC-MASTARSSP')
    st_vel = maps.stellar_vel.value
    oiii_ew = maps.emline_gew_oiii_5008.value
    phi = maps.spx_ellcoo_elliptical_azimuth.value
    r_re = maps.spx_ellcoo_r_re.value
    
    axis_indicat = np.zeros(phi.shape)

    for i in range(phi.shape[0]):
        for j in range(phi.shape[1]):
            if phi[i][j] >= 88 and phi[i][j] <= 92:
                axis_indicat[i][j] = 1
            elif phi[i][j] >= 268 and phi[i][j] <= 272:
                axis_indicat[i][j] = 1
            elif r_re[i][j] >= 0.9 and r_re[i][j] <=1.1:
                axis_indicat[i][j] = 1
            else:
                pass
            
            
            
            
    plt.figure()
    plt.imshow(st_vel, cmap='viridis')
    plt.imshow(axis_indicat, 'Greys', alpha = 0.3)
    plt.title(r'$V_{stellar}$')
    plt.gca().invert_yaxis()
    plt.colorbar(orientation='vertical',label = r'$km/s$')
    plt.savefig(data+'.png')

# %%
def marvin_major_axis(data):
    
    dapall_index = list(plateifu).index(data)
    p_slope = np.tan(petro_angle[dapall_index])
    s_slope = np.tan(sersic_angle[dapall_index])

    maps = Maps(data, bintype='SPX', template='MILESHC-MASTARSSP')
    st_vel = maps.stellar_vel
    #oiii_ew = maps.emline_gew_oiii_5008.value
    phi = maps.spx_ellcoo_elliptical_azimuth.value
    r_re = maps.spx_ellcoo_r_re.value

    axis_indicat = np.zeros(phi.shape)

    for i in range(phi.shape[0]):
        for j in range(phi.shape[1]):
            if phi[i][j] >= 88 and phi[i][j] <= 92:
                axis_indicat[i][j] = 1
            elif phi[i][j] >= 268 and phi[i][j] <= 272:
                axis_indicat[i][j] = 1
            elif r_re[i][j] >= 0.9 and r_re[i][j] <=1.1:
                axis_indicat[i][j] = 1
            else:
                pass


    st_vel.plot(snr_min = None)
    plt.imshow(axis_indicat, 'Greys', alpha = 0.3)
    plt.savefig(data+'.png')

# %% [markdown]
# ## Multi-processing
#
#
# if __name__ == '__main__':
#     pool = mp.Pool(processes=4)
#
#     pool.imap_unordered(marvin_major_axis, plateifu_2):
#         results.append(result)
#
#     print(results)

# %% [markdown]
# ## Plotting
#
# SAMPLE_PATH = '/Users/runquanguan/Documents/bicone_training_set.fits'
# hdul_2 = fits.open(SAMPLE_PATH)
# hdu_2 = hdul_2[1].data
# plateifu_2 = hdu_2['PLATEIFU']
#
#
# for i in plateifu_2:
#     marvin_major_axis(i)

# %% [markdown]
# # Ploting axis over image

# %%
def image_major_axis(data):

    dapall_index = list(plateifu).index(data)
    p_slope = np.tan(petro_angle[dapall_index])
    s_slope = np.tan(sersic_angle[dapall_index])

    maps = Maps(data, bintype='SPX', template='MILESHC-MASTARSSP')
    st_vel = maps.stellar_vel
    #oiii_ew = maps.emline_gew_oiii_5008.value
    phi = maps.spx_ellcoo_elliptical_azimuth.value
    r_re = maps.spx_ellcoo_r_re.value

    axis_indicat = np.zeros(phi.shape)

    for i in range(phi.shape[0]):
        for j in range(phi.shape[1]):
            if phi[i][j] >= 88 and phi[i][j] <= 92:
                axis_indicat[i][j] = 100
            elif phi[i][j] >= 268 and phi[i][j] <= 272:
                axis_indicat[i][j] = 100
            elif r_re[i][j] >= 0.9 and r_re[i][j] <=1.1:
                axis_indicat[i][j] = 100
            else:
                pass
            
    im = Image(data)

    spaxel_len = 281*2
    factor = spaxel_len / axis_indicat.shape[0]

    large_mask = ndimage.zoom(axis_indicat, factor, order=0)
    # large_mask[large_mask > 0] = 1


    mask = np.flipud(large_mask)
    im = showImage(plateifu = data)
    masked = np.ma.masked_where(mask == 0, mask)

    plt.imshow(im, interpolation='none')
    plt.imshow(masked, 'autumn', interpolation='none', alpha=0.7)
    plt.savefig(data+'_image.png')

# %%
## Plotting

SAMPLE_PATH = '/Users/runquanguan/Documents/bicone_training_set.fits'
hdul_2 = fits.open(SAMPLE_PATH)
hdu_2 = hdul_2[1].data
plateifu_2 = hdu_2['PLATEIFU']


for i in plateifu_2:
    image_major_axis(i)
# Out:
# [WARNING]: unclosed file <_io.FileIO name='/Users/runquanguan/Documents/bicone_training_set.fits' mode='rb' closefd=True> (ResourceWarning)
# [WARNING]: showImage is deprecated as of Marvin 2.3.0. Please use marvin.tools.image.Image instead. (MarvinDeprecationWarning)
# [WARNING]: subprocess 16207 is still running (ResourceWarning)
# [WARNING]: subprocess 16214 is still running (ResourceWarning)
# [WARNING]: subprocess 16220 is still running (ResourceWarning)
# [WARNING]: subprocess 16225 is still running (ResourceWarning)
# [WARNING]: subprocess 16235 is still running (ResourceWarning)
# [WARNING]: subprocess 16241 is still running (ResourceWarning)
# [WARNING]: subprocess 16246 is still running (ResourceWarning)
# [WARNING]: subprocess 16259 is still running (ResourceWarning)
# [WARNING]: subprocess 16265 is still running (ResourceWarning)
# [WARNING]: subprocess 16272 is still running (ResourceWarning)
# [WARNING]: subprocess 16278 is still running (ResourceWarning)
# [WARNING]: subprocess 16284 is still running (ResourceWarning)
# [WARNING]: subprocess 16289 is still running (ResourceWarning)
# [WARNING]: subprocess 16295 is still running (ResourceWarning)
# [WARNING]: subprocess 16300 is still running (ResourceWarning)
# [WARNING]: subprocess 16306 is still running (ResourceWarning)
# [WARNING]: subprocess 16313 is still running (ResourceWarning)
# [WARNING]: subprocess 16319 is still running (ResourceWarning)
# [WARNING]: subprocess 16325 is still running (ResourceWarning)
# [WARNING]: subprocess 16331 is still running (ResourceWarning)
# [WARNING]: subprocess 16337 is still running (ResourceWarning)
# [WARNING]: subprocess 16343 is still running (ResourceWarning)
# [WARNING]: subprocess 16349 is still running (ResourceWarning)
# [WARNING]: subprocess 16356 is still running (ResourceWarning)
# [WARNING]: subprocess 16362 is still running (ResourceWarning)
# [WARNING]: subprocess 16373 is still running (ResourceWarning)
# [WARNING]: subprocess 16379 is still running (ResourceWarning)
# [WARNING]: subprocess 16386 is still running (ResourceWarning)
# [WARNING]: subprocess 16395 is still running (ResourceWarning)
# [WARNING]: subprocess 16401 is still running (ResourceWarning)
# [WARNING]: subprocess 16407 is still running (ResourceWarning)
# [WARNING]: subprocess 16413 is still running (ResourceWarning)
# [WARNING]: subprocess 16419 is still running (ResourceWarning)
# [WARNING]: subprocess 16425 is still running (ResourceWarning)
# [WARNING]: subprocess 16431 is still running (ResourceWarning)
# [WARNING]: subprocess 16437 is still running (ResourceWarning)
# [WARNING]: subprocess 16446 is still running (ResourceWarning)
# [WARNING]: subprocess 16470 is still running (ResourceWarning)
# [WARNING]: subprocess 16477 is still running (ResourceWarning)
# [WARNING]: subprocess 16484 is still running (ResourceWarning)
# [WARNING]: subprocess 16492 is still running (ResourceWarning)
# [WARNING]: subprocess 16498 is still running (ResourceWarning)
# [WARNING]: subprocess 16504 is still running (ResourceWarning)
# [WARNING]: subprocess 16511 is still running (ResourceWarning)
# [WARNING]: subprocess 16518 is still running (ResourceWarning)
# [WARNING]: subprocess 16524 is still running (ResourceWarning)
# [WARNING]: subprocess 16530 is still running (ResourceWarning)
# [WARNING]: subprocess 16536 is still running (ResourceWarning)
# [WARNING]: subprocess 16542 is still running (ResourceWarning)
# [WARNING]: subprocess 16548 is still running (ResourceWarning)
# [WARNING]: subprocess 16554 is still running (ResourceWarning)
# [WARNING]: subprocess 16560 is still running (ResourceWarning)
# [WARNING]: subprocess 16566 is still running (ResourceWarning)
# [WARNING]: subprocess 16572 is still running (ResourceWarning)
# [WARNING]: subprocess 16578 is still running (ResourceWarning)
# [WARNING]: subprocess 16585 is still running (ResourceWarning)
# [WARNING]: subprocess 16591 is still running (ResourceWarning)
# [WARNING]: subprocess 16597 is still running (ResourceWarning)
# [WARNING]: subprocess 16605 is still running (ResourceWarning)
# [WARNING]: subprocess 16611 is still running (ResourceWarning)
# [WARNING]: subprocess 16623 is still running (ResourceWarning)
# [WARNING]: subprocess 16634 is still running (ResourceWarning)
# [WARNING]: subprocess 16641 is still running (ResourceWarning)
# [WARNING]: subprocess 16647 is still running (ResourceWarning)
# [WARNING]: subprocess 16654 is still running (ResourceWarning)
# [WARNING]: subprocess 16659 is still running (ResourceWarning)
# [WARNING]: subprocess 16665 is still running (ResourceWarning)
# [WARNING]: subprocess 16671 is still running (ResourceWarning)
# [WARNING]: subprocess 16677 is still running (ResourceWarning)
# [WARNING]: subprocess 16684 is still running (ResourceWarning)
# [WARNING]: subprocess 16690 is still running (ResourceWarning)
# [WARNING]: subprocess 16696 is still running (ResourceWarning)
# [WARNING]: subprocess 16701 is still running (ResourceWarning)
# [WARNING]: subprocess 16708 is still running (ResourceWarning)
# [WARNING]: subprocess 16715 is still running (ResourceWarning)
# [WARNING]: subprocess 16722 is still running (ResourceWarning)
# [WARNING]: subprocess 16728 is still running (ResourceWarning)
# [WARNING]: subprocess 16734 is still running (ResourceWarning)
# [WARNING]: subprocess 16742 is still running (ResourceWarning)
# [WARNING]: subprocess 16749 is still running (ResourceWarning)
# [WARNING]: subprocess 16758 is still running (ResourceWarning)
# [WARNING]: subprocess 16764 is still running (ResourceWarning)
# [WARNING]: subprocess 16771 is still running (ResourceWarning)
# [WARNING]: subprocess 16777 is still running (ResourceWarning)
# [WARNING]: subprocess 16783 is still running (ResourceWarning)
# [WARNING]: subprocess 16789 is still running (ResourceWarning)
# [WARNING]: subprocess 16795 is still running (ResourceWarning)
# [WARNING]: subprocess 16802 is still running (ResourceWarning)
# [WARNING]: subprocess 16807 is still running (ResourceWarning)
# [WARNING]: subprocess 16813 is still running (ResourceWarning)
# [WARNING]: subprocess 16820 is still running (ResourceWarning)
# [WARNING]: subprocess 16827 is still running (ResourceWarning)
# [WARNING]: subprocess 16833 is still running (ResourceWarning)
# [WARNING]: subprocess 16840 is still running (ResourceWarning)
# [WARNING]: subprocess 16845 is still running (ResourceWarning)
# [WARNING]: subprocess 16851 is still running (ResourceWarning)
# [WARNING]: subprocess 16857 is still running (ResourceWarning)
# [WARNING]: subprocess 16863 is still running (ResourceWarning)
# [WARNING]: subprocess 16869 is still running (ResourceWarning)
# [WARNING]: subprocess 16876 is still running (ResourceWarning)
# [WARNING]: subprocess 16883 is still running (ResourceWarning)
# [WARNING]: subprocess 16889 is still running (ResourceWarning)
# [WARNING]: subprocess 16894 is still running (ResourceWarning)
# [WARNING]: subprocess 16901 is still running (ResourceWarning)
# [WARNING]: subprocess 16907 is still running (ResourceWarning)
# [WARNING]: subprocess 16914 is still running (ResourceWarning)
# [WARNING]: subprocess 16920 is still running (ResourceWarning)
# [WARNING]: subprocess 16926 is still running (ResourceWarning)
# [WARNING]: subprocess 16932 is still running (ResourceWarning)
# [WARNING]: subprocess 16937 is still running (ResourceWarning)
# [WARNING]: subprocess 16944 is still running (ResourceWarning)
# [WARNING]: subprocess 16950 is still running (ResourceWarning)
# [WARNING]: subprocess 16956 is still running (ResourceWarning)
# [WARNING]: subprocess 16962 is still running (ResourceWarning)
# [WARNING]: subprocess 16968 is still running (ResourceWarning)
# [WARNING]: subprocess 16974 is still running (ResourceWarning)
# [WARNING]: subprocess 16981 is still running (ResourceWarning)
# [WARNING]: subprocess 16987 is still running (ResourceWarning)
# [WARNING]: subprocess 16993 is still running (ResourceWarning)
# [WARNING]: subprocess 16999 is still running (ResourceWarning)
# [WARNING]: subprocess 17005 is still running (ResourceWarning)
# [WARNING]: subprocess 17011 is still running (ResourceWarning)
# [WARNING]: subprocess 17017 is still running (ResourceWarning)
# [WARNING]: subprocess 17023 is still running (ResourceWarning)
# [WARNING]: subprocess 17029 is still running (ResourceWarning)
# [WARNING]: subprocess 17036 is still running (ResourceWarning)
# [WARNING]: subprocess 17062 is still running (ResourceWarning)
# [WARNING]: subprocess 17070 is still running (ResourceWarning)
# [WARNING]: subprocess 17081 is still running (ResourceWarning)
# [WARNING]: subprocess 17100 is still running (ResourceWarning)
# [WARNING]: subprocess 17127 is still running (ResourceWarning)
# [WARNING]: subprocess 17133 is still running (ResourceWarning)
# [WARNING]: subprocess 17142 is still running (ResourceWarning)
# [WARNING]: subprocess 17148 is still running (ResourceWarning)
# [WARNING]: subprocess 17154 is still running (ResourceWarning)
# [WARNING]: subprocess 17160 is still running (ResourceWarning)
# [WARNING]: subprocess 17166 is still running (ResourceWarning)
# [WARNING]: subprocess 17172 is still running (ResourceWarning)
# [WARNING]: subprocess 17178 is still running (ResourceWarning)
# [WARNING]: subprocess 17184 is still running (ResourceWarning)
# [WARNING]: subprocess 17190 is still running (ResourceWarning)
# [WARNING]: subprocess 17196 is still running (ResourceWarning)
# [WARNING]: subprocess 17202 is still running (ResourceWarning)
# [WARNING]: subprocess 17208 is still running (ResourceWarning)
# [WARNING]: subprocess 17214 is still running (ResourceWarning)
# [WARNING]: subprocess 17220 is still running (ResourceWarning)
# [WARNING]: subprocess 17226 is still running (ResourceWarning)
# [WARNING]: subprocess 17233 is still running (ResourceWarning)
# [WARNING]: subprocess 17240 is still running (ResourceWarning)
# [WARNING]: subprocess 17246 is still running (ResourceWarning)
# [WARNING]: subprocess 17252 is still running (ResourceWarning)
# [WARNING]: subprocess 17258 is still running (ResourceWarning)
# [WARNING]: subprocess 17265 is still running (ResourceWarning)
# [WARNING]: subprocess 17271 is still running (ResourceWarning)
# [WARNING]: subprocess 17279 is still running (ResourceWarning)
# [WARNING]: subprocess 17285 is still running (ResourceWarning)

# %%
data = '8320-1901'

dapall_index = list(plateifu).index(data)
p_slope = np.tan(petro_angle[dapall_index])
s_slope = np.tan(sersic_angle[dapall_index])

maps = Maps(data, bintype='SPX', template='MILESHC-MASTARSSP')
st_vel = maps.stellar_vel
#oiii_ew = maps.emline_gew_oiii_5008.value
phi = maps.spx_ellcoo_elliptical_azimuth.value
r_re = maps.spx_ellcoo_r_re.value

axis_indicat = np.zeros(phi.shape)

for i in range(phi.shape[0]):
    for j in range(phi.shape[1]):
        if phi[i][j] >= 88 and phi[i][j] <= 92:
            axis_indicat[i][j] = 100
        elif phi[i][j] >= 268 and phi[i][j] <= 272:
            axis_indicat[i][j] = 100
        elif r_re[i][j] >= 0.9 and r_re[i][j] <=1.1:
            axis_indicat[i][j] = 100
        else:
            pass

# %%
#im = Image(data)

spaxel_len = 281*2
factor = spaxel_len / axis_indicat.shape[0]

large_mask = ndimage.zoom(axis_indicat, factor, order=0)
#large_mask[large_mask > 0] = 1


mask = np.flipud(large_mask)
im = showImage(plateifu = data)
masked = np.ma.masked_where(mask == 0, mask)

plt.imshow(im, interpolation='none')
plt.imshow(masked, 'autumn', interpolation='none', alpha=0.7)
#plt.savefig(data+'_image.png')
plt.show()
