# %% [markdown]
# Information about MAPS file can be found here:
#     https://data.sdss.org/datamodel/files/MANGA_SPECTRO_ANALYSIS/DRPVER/DAPVER/DAPTYPE/PLATE/IFU/manga-MAPS-DAPTYPE.html
#
#
# The goal is to plot stellar velocity field, gas velocity field, OIII[5007] EW field. Using Song's color
#
# Jun 16: obvious_bicone_feature_position.fits file missing

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename

# %% [markdown]
# ## Locationg specific MAPS fits file

# %%
plateifu = '8486-12705'

FOLDER = '/Users/runquanguan/Documents/Research/MaNGA-AGN/Data/'
FILENAME = 'manga-' + plateifu + '-MAPS-SPX-MILESHC-MASTARSSP.fits'

PATH = FOLDER+FILENAME

hdul = fits.open(PATH)

# %% [markdown]
# ## Plotting some figure: velocity, EW

# %%
image_file = get_pkg_data_filename(PATH)

#Line-of-sight stellar velocity,
STELLAR_VEL = fits.getdata(image_file, ext=15)
#Non-parametric equivalent widths measurements
EMLINE_SEW = fits.getdata(image_file, ext=26)
#Line-of-sight emission-line velocity
EMLINE_GVEL = fits.getdata(image_file, ext=37)
#Gaussian-fitted equivalent widths measurements
EMLINE_GEW = fits.getdata(image_file, ext=33)

#Channel of Elements: 
#'OIII-5008'          / Data in channel 17 
#'Ha-6564 '           / Data in channel 24
#'Hb-4862 '           / Data in channel 15
#'NII-6585'           / Data in channel 25
#'SII-6732'           / Data in channel 27
DATA = np.log(EMLINE_GVEL[16])
# Out:
# /Users/runquanguan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in log
# /Users/runquanguan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in log

# %%
#fig = plt.figure(figsize=(6,6))

plt.imshow(DATA, cmap='viridis')
plt.title(r'$EW_{OIII}$')
plt.gca().invert_yaxis()
plt.colorbar(orientation='vertical',label = r'$log(\AA)$')
plt.show()
